# %% [markdown]
# # Chapter 4 - Full syndromic dataset (pairwise)

# %% [markdown]
# ## Setup

# %% [markdown]
# Run Python file to import libraries and custom functions

# %%
# %run libraries.py
# Out:
# Using TensorFlow backend.
# /Users/joefarrington/anaconda3/lib/python3.6/site-packages/sklearn/externals/six.py:31: DeprecationWarning: The module is deprecated in version 0.21 and will be removed in version 0.23 since we've dropped support for Python 2.7. Please rely on the official version of six (https://pypi.org/project/six/).
#   "(https://pypi.org/project/six/).", DeprecationWarning)
# /Users/joefarrington/anaconda3/lib/python3.6/site-packages/sklearn/externals/joblib/__init__.py:15: DeprecationWarning: sklearn.externals.joblib is deprecated in 0.21 and will be removed in 0.23. Please import this functionality directly from joblib, which can be installed with: pip install joblib. If this warning is raised when loading pickled models, you may need to re-serialize those models with scikit-learn 0.21+.
#   warnings.warn(msg, category=DeprecationWarning)

# %% [markdown]
# Set paths for data and models

# %%
data_path = '/Users/joefarrington/Documents/MSc Machine Learning/Project/August/Data for import/'
results_path = '/Users/joefarrington/Documents/MSc Machine Learning/Project/August/Results/Ch4Allpairwise/'

# %% [markdown]
# Define a string to be added to the name of all saved results from this notebook

# %%
nbname = 'Ch4Allpairwise'

# %% [markdown]
# Import the data

# %%
X_all = pd.read_csv(data_path+'X_all_Rev.csv', index_col=0)
y_all = np.array(pd.read_csv(data_path+'y_all_Rev.csv', index_col=0, header=None)).reshape(-1,)

# %% [markdown]
# Define an sklearn scorer object to calculate the Matthews Correlation Coefficient (MCC)

# %%
mcc_scorer = make_scorer(matthews_corrcoef)

# %% [markdown]
# Define a named tuple to store the results

# %% [markdown]
# Create a list that contains the labels

# %%
B_labels = np.unique(y_all)
B_labels[1] = 'DS'
B_labels
# Out:
# array(['22q11DS', 'DS', 'FXS-F', 'FXS-M', 'NF1', 'PW-UPD', 'PW-del',
#        'SMC15', 'TSC', 'XXY'], dtype=object)

# %% [markdown]
# Define a function to get pairwise data

# %%
def get_pairwise_data(class1, class2, X, y):
    
    """
    Returns the training data for a pairwise comparison
    
    Inputs
    class1 - a class label
    class2 - a class label
    X - Pandas dataframe of training data
    y - NumPy array of training labels
    
    Outputs
    X_c - Pandas dataframe of training data for class1 and class2 only
    y_c - NumPy array of training labels for class1 and class2 only
    """
    
    y_c = y[(y==class1) | (y == class2)]
    X_c = X[(y==class1) | (y ==class2)]
    
    return X_c, y_c

# %% [markdown]
# Get the labels (as they are in y) and all of the pairwise combinations

# %%
labels = np.unique(y_all)

# %%
comparisons = list(itertools.combinations(labels, 2))

# %% [markdown]
# Set the number of repeats (train/test splits) and fold (for cross-validation)

# %%
n_repeats = 10
n_folds = 10

# %% [markdown]
# ## Model 1: OvO SVM with RBF kernel

# %% [markdown]
# Define a subfolder to store the results

# %%
subfolder = 'SVM_RBF/'

# %% [markdown]
# Define the model

# %%
svc_rbf = SVC(decision_function_shape='ovo', kernel='rbf')
steps_rbf = [('scaler', StandardScaler()),
     ('model',svc_rbf)]
pipeline_rbf = Pipeline(steps_rbf)

# %% [markdown]
# Define the parameters for the grid search

# %%
rbf_C_range = np.logspace(start=-5, stop=15, num=21, base=2)
rbf_gamma_range = np.logspace(start=-15, stop=3, num=19, base=2)
rbf_parameters = dict(model__gamma=rbf_gamma_range, model__C=rbf_C_range)

# %% [markdown]
# Create dataframes to store the pairwise results

# %%
mean_mcc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)
std_mcc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)

mean_acc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)
std_acc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)

# %% [markdown]
# Train the pairwise models and store the results

# %%
overall_res = {}

for comp in comparisons:
    
    X_c, y_c = get_pairwise_data(comp[0], comp[1], X_all, y_all)
    results_dict = repeated_training(X_c, y_c, n_repeats, n_folds, rbf_parameters, pipeline_rbf, mcc_scorer, verbose=1)
    
    rkeys = [x for x in results_dict.keys()][:-1]
    acc = []
    for key in rkeys:
        acc.append(results_dict[key].acc_test)
    mean_acc_df.loc[comp[0], comp[1]] = np.mean(acc)
    std_acc_df.loc[comp[0], comp[1]] = np.std(acc)

    mcc = []
    for key in rkeys:
        mcc.append(results_dict[key].mcc_test)
    mean_mcc_df.loc[comp[0], comp[1]] = np.mean(mcc)
    std_mcc_df.loc[comp[0], comp[1]] = np.std(mcc)
    
    overall_res[comp] = results_dict
# Out:
# Fitting 10 folds for each of 399 candidates, totalling 3990 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:    1.8s
# [Parallel(n_jobs=-1)]: Done 1586 tasks      | elapsed:    4.1s
# [Parallel(n_jobs=-1)]: Done 3990 out of 3990 | elapsed:    7.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Run 0 completed
# Fitting 10 folds for each of 399 candidates, totalling 3990 fits
# [Parallel(n_jobs=-1)]: Done 520 tasks      | elapsed:    1.9s
# [Parallel(n_jobs=-1)]: Done 3990 out of 3990 | elapsed:    8.8s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Run 1 completed
# Fitting 10 folds for each of 399 candidates, totalling 3990 fits
# [Parallel(n_jobs=-1)]: Done 376 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 3376 tasks      | elapsed:    7.9s
# ...

# %% [markdown]
# Save the dataframes as CSVs

# %%
mean_mcc_df.to_csv(results_path+subfolder+'mean_mcc_pairwise.csv')
std_mcc_df.to_csv(results_path+subfolder+'std_mcc_pairwise.csv')
mean_acc_df.to_csv(results_path+subfolder+'mean_acc_pairwise.csv')
std_mcc_df.to_csv(results_path+subfolder+'std_acc_pairwise.csv')

# %%
pickle_dump(overall_res, results_path+subfolder+f"overall_res_{nbname}.p")
# Out:
# writing total_bytes=55219867...
# writing bytes [0, 55219867)... done.

# %% [markdown]
# Print the results

# %%
mean_mcc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.528133  0.593306  0.851568  0.685337  0.725643  0.775950
# Down         0.0  0.000000  0.714713  0.771487  0.663013 -0.051135  0.247415
# FXS-F        0.0  0.000000  0.000000  0.522707  0.524038  0.833950  0.843086
# FXS-M        0.0  0.000000  0.000000  0.000000  0.403202  0.827591  0.912526
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.751142  0.822434
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.045354
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.921601  0.635543  0.518299
# Down     0.710164  0.631107  0.476154
# ...

# %%
std_mcc_df
# Out:
#          22q11DS    Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.1845  0.173082  0.069608  0.172401  0.147602  0.090305
# Down         0.0  0.0000  0.136173  0.184880  0.157767  0.194446  0.215062
# FXS-F        0.0  0.0000  0.000000  0.216337  0.161083  0.132243  0.094826
# FXS-M        0.0  0.0000  0.000000  0.000000  0.135896  0.120091  0.067561
# NF1          0.0  0.0000  0.000000  0.000000  0.000000  0.186332  0.078067
# PW-UPD       0.0  0.0000  0.000000  0.000000  0.000000  0.000000  0.201419
# PW-del       0.0  0.0000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.0000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.0000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.0000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.073968  0.088552  0.118281
# Down     0.089345  0.188490  0.128923
# ...

# %%
mean_acc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.833333  0.818519  0.922857  0.853571  0.877778  0.896429
# Down         0.0  0.000000  0.853333  0.913636  0.826667  0.513333  0.662500
# FXS-F        0.0  0.000000  0.000000  0.784615  0.757895  0.911111  0.915789
# FXS-M        0.0  0.000000  0.000000  0.000000  0.719231  0.919231  0.957692
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.868421  0.905000
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.542105
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.968000  0.824444  0.782143
# Down     0.846154  0.893939  0.756250
# ...

# %%
std_acc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.067185  0.080209  0.036253  0.075677  0.064257  0.040564
# Down         0.0  0.000000  0.065320  0.062490  0.085375  0.079162  0.080039
# FXS-F        0.0  0.000000  0.000000  0.102050  0.078772  0.071146  0.053674
# FXS-M        0.0  0.000000  0.000000  0.000000  0.057177  0.052876  0.031949
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.097759  0.041533
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.074618
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.029933  0.042687  0.051632
# Down     0.048650  0.047432  0.058962
# ...

# %% [markdown]
# ## Model 2: OvO SVM with linear kernel

# %% [markdown]
# Define a subfolder to store the results

# %%
subfolder = 'SVM_lin/'

# %% [markdown]
# Define the model

# %%
svc_lin = SVC(decision_function_shape='ovo', kernel='linear')
steps_lin = [('scaler', StandardScaler()),
     ('model',svc_lin)]
pipeline_lin = Pipeline(steps_lin)

# %% [markdown]
# Define the parameters for the grid search

# %%
lin_C_range = np.logspace(start=-10, stop=10, num=21, base=2)
lin_parameters = dict(model__C=lin_C_range)

# %% [markdown]
# Create dataframes to store the pairwise results

# %%
mean_mcc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)
std_mcc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)

mean_acc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)
std_acc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)

# %% [markdown]
# Train the pairwise models and store the results

# %%
overall_res = {}

for comp in comparisons:
    
    X_c, y_c = get_pairwise_data(comp[0], comp[1], X_all, y_all)
    results_dict = repeated_training(X_c, y_c, n_repeats, n_folds, lin_parameters, pipeline_lin, mcc_scorer, verbose=1)
    
    rkeys = [x for x in results_dict.keys()][:-1]
    acc = []
    for key in rkeys:
        acc.append(results_dict[key].acc_test)
    mean_acc_df.loc[comp[0], comp[1]] = np.mean(acc)
    std_acc_df.loc[comp[0], comp[1]] = np.std(acc)

    mcc = []
    for key in rkeys:
        mcc.append(results_dict[key].mcc_test)
    mean_mcc_df.loc[comp[0], comp[1]] = np.mean(mcc)
    std_mcc_df.loc[comp[0], comp[1]] = np.std(mcc)
    
    overall_res[comp] = results_dict
# Out:
# Fitting 10 folds for each of 21 candidates, totalling 210 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 210 out of 210 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Run 0 completed
# Fitting 10 folds for each of 21 candidates, totalling 210 fits
# [Parallel(n_jobs=-1)]: Done 210 out of 210 | elapsed:    0.3s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Run 1 completed
# Fitting 10 folds for each of 21 candidates, totalling 210 fits
# [Parallel(n_jobs=-1)]: Done 210 out of 210 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# Run 2 completed
# Fitting 10 folds for each of 21 candidates, totalling 210 fits
# [Parallel(n_jobs=-1)]: Done 210 out of 210 | elapsed:    0.4s finished
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# ...

# %% [markdown]
# Save the dataframes as CSVs

# %%
mean_mcc_df.to_csv(results_path+subfolder+'mean_mcc_pairwise.csv')
std_mcc_df.to_csv(results_path+subfolder+'std_mcc_pairwise.csv')
mean_acc_df.to_csv(results_path+subfolder+'mean_acc_pairwise.csv')
std_mcc_df.to_csv(results_path+subfolder+'std_acc_pairwise.csv')

# %%
pickle_dump(overall_res, results_path+subfolder+f"overall_res_{nbname}.p")
# Out:
# writing total_bytes=25203179...
# writing bytes [0, 25203179)... done.

# %% [markdown]
# Print the results

# %%
mean_mcc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.470269  0.610356  0.799778  0.621718  0.747236  0.792601
# Down         0.0  0.000000  0.716811  0.820395  0.610985  0.100838  0.276769
# FXS-F        0.0  0.000000  0.000000  0.581077  0.464876  0.822116  0.876722
# FXS-M        0.0  0.000000  0.000000  0.000000  0.410229  0.804010  0.803268
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.692715  0.745465
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000 -0.032524
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.930742  0.683951  0.385580
# Down     0.681646  0.594008  0.454732
# ...

# %%
std_mcc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.215844  0.166560  0.082660  0.105123  0.130535  0.114230
# Down         0.0  0.000000  0.133428  0.125504  0.170523  0.169913  0.264560
# FXS-F        0.0  0.000000  0.000000  0.144124  0.166229  0.108788  0.102138
# FXS-M        0.0  0.000000  0.000000  0.000000  0.197100  0.131471  0.129832
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.129369  0.111773
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.240705
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.063405  0.148092  0.168708
# Down     0.151004  0.157102  0.229618
# ...

# %%
mean_acc_df
# Out:
#          22q11DS      Down    FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.804167  0.82963  0.894286  0.828571  0.888889  0.903571
# Down         0.0  0.000000  0.86000  0.931818  0.800000  0.586667  0.662500
# FXS-F        0.0  0.000000  0.00000  0.815385  0.726316  0.905556  0.936842
# FXS-M        0.0  0.000000  0.00000  0.000000  0.723077  0.907692  0.903846
# NF1          0.0  0.000000  0.00000  0.000000  0.000000  0.836842  0.865000
# PW-UPD       0.0  0.000000  0.00000  0.000000  0.000000  0.000000  0.484211
# PW-del       0.0  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.00000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.972000  0.844444  0.725000
# Down     0.830769  0.887879  0.743750
# ...

# %%
std_acc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.056057  0.070662  0.044355  0.047380  0.054935  0.053093
# Down         0.0  0.000000  0.062893  0.046577  0.084327  0.058119  0.105327
# FXS-F        0.0  0.000000  0.000000  0.061538  0.084211  0.061111  0.051568
# FXS-M        0.0  0.000000  0.000000  0.000000  0.087368  0.060079  0.062611
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.064245  0.059372
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.102056
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.025612  0.072350  0.067857
# Down     0.082849  0.038450  0.098623
# ...

# %% [markdown]
# ## Model 3: Naive Bayes (learn prior)

# %% [markdown]
# See '<b>Pairwise Naive Bayes in R.ipynb</b>'

# %% [markdown]
# ## Model 4: Naive Bayes (uniform prior)

# %% [markdown]
# See '<b>Pairwise Naive Bayes in R.ipynb</b>'

# %% [markdown]
# ## Model 5: Standard Random Forest

# %% [markdown]
# Define a subfolder to store the results

# %%
subfolder = 'SRF/'

# %% [markdown]
# Define the model

# %%
rfc_naive = RandomForestClassifier()

# %% [markdown]
# Define the parameters for the grid search

# %%
n_features = X_all.shape[1]
default_mtry = np.sqrt(n_features)
rfc_parameters = {'max_features': [int(0.5*default_mtry), int(default_mtry), int(1.5*default_mtry), int(2*default_mtry), int(3*default_mtry)],
             'n_estimators': [2000], 'min_samples_leaf': [1,2, 3, 4, 5]}

# %% [markdown]
# Create dataframes to store the pairwise results

# %%
mean_mcc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)
std_mcc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)

mean_acc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)
std_acc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)

# %% [markdown]
# Train the pairwise models and store the results

# %%
overall_res = {}

for comp in comparisons:
    
    X_c, y_c = get_pairwise_data(comp[0], comp[1], X_all, y_all)
    results_dict = repeated_training(X_c, y_c, n_repeats, n_folds, rfc_parameters, rfc_naive, mcc_scorer, verbose=1)
    
    rkeys = [x for x in results_dict.keys()][:-1]
    acc = []
    for key in rkeys:
        acc.append(results_dict[key].acc_test)
    mean_acc_df.loc[comp[0], comp[1]] = np.mean(acc)
    std_acc_df.loc[comp[0], comp[1]] = np.std(acc)

    mcc = []
    for key in rkeys:
        mcc.append(results_dict[key].mcc_test)
    mean_mcc_df.loc[comp[0], comp[1]] = np.mean(mcc)
    std_mcc_df.loc[comp[0], comp[1]] = np.std(mcc)
    
    overall_res[comp] = results_dict
# Out:
# Fitting 10 folds for each of 25 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   16.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  1.8min finished
# Run 0 completed
# Fitting 10 folds for each of 25 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   16.2s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  1.8min finished
# Run 1 completed
# Fitting 10 folds for each of 25 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   18.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.3min
# ...

# %% [markdown]
# Save the dataframes as CSVs

# %%
mean_mcc_df.to_csv(results_path+subfolder+'mean_mcc_pairwise.csv')
std_mcc_df.to_csv(results_path+subfolder+'std_mcc_pairwise.csv')
mean_acc_df.to_csv(results_path+subfolder+'mean_acc_pairwise.csv')
std_mcc_df.to_csv(results_path+subfolder+'std_acc_pairwise.csv')

# %%
pickle_dump(overall_res, results_path+subfolder+f"overall_res_{nbname}.p")
# Out:
# writing total_bytes=2272620117...
# writing bytes [0, 1073741824)... done.
# writing bytes [1073741824, 2147483648)... done.
# writing bytes [2147483648, 2272620117)... done.

# %% [markdown]
# Print the results

# %%
mean_mcc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.699018  0.634608  0.798169  0.650855  0.773943  0.715146
# Down         0.0  0.000000  0.735904  0.863890  0.639694  0.071143  0.234248
# FXS-F        0.0  0.000000  0.000000  0.448254  0.414886  0.840423  0.826678
# FXS-M        0.0  0.000000  0.000000  0.000000  0.525329  0.830461  0.880622
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.871098  0.845406
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000 -0.067895
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.960404  0.647183  0.633886
# Down     0.797836  0.424459  0.570718
# ...

# %%
std_mcc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.142198  0.096861  0.082000  0.173965  0.122074  0.055644
# Down         0.0  0.000000  0.157270  0.114547  0.173200  0.191440  0.212358
# FXS-F        0.0  0.000000  0.000000  0.189630  0.155624  0.119090  0.141585
# FXS-M        0.0  0.000000  0.000000  0.000000  0.168602  0.102595  0.090441
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.090429  0.125373
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.218964
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.065698  0.060093  0.137746
# Down     0.114055  0.229351  0.177625
# ...

# %%
mean_acc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.891667  0.837037  0.897143  0.839286  0.900000  0.864286
# Down         0.0  0.000000  0.853333  0.950000  0.826667  0.593333  0.650000
# FXS-F        0.0  0.000000  0.000000  0.761538  0.705263  0.916667  0.910526
# FXS-M        0.0  0.000000  0.000000  0.000000  0.776923  0.923077  0.942308
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.931579  0.920000
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.468421
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.984000  0.828889  0.832143
# Down     0.892308  0.857576  0.800000
# ...

# %%
std_acc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.046398  0.044444  0.040808  0.073627  0.052509  0.026726
# Down         0.0  0.000000  0.093333  0.042882  0.085375  0.069602  0.089268
# FXS-F        0.0  0.000000  0.000000  0.076537  0.078772  0.062113  0.070809
# FXS-M        0.0  0.000000  0.000000  0.000000  0.072569  0.045508  0.043001
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.047368  0.064031
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.109012
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.026533  0.028197  0.057698
# Down     0.061538  0.050797  0.078062
# ...

# %% [markdown]
# ## Model 6: Balanced Random Forest

# %% [markdown]
# Define a subfolder to store the results

# %%
subfolder = 'BRF/'

# %% [markdown]
# Define the model

# %%
rfc_bal = BalancedRandomForestClassifier()

# %% [markdown]
# Define the parameters for the grid search

# %%
n_features = X_all.shape[1]
default_mtry = np.sqrt(n_features)
rfc_parameters = {'max_features': [int(0.5*default_mtry), int(default_mtry), int(1.5*default_mtry), int(2*default_mtry), int(3*default_mtry)],
             'n_estimators': [2000], 'min_samples_leaf': [1,2, 3, 4, 5]}

# %% [markdown]
# Create dataframes to store the results

# %%
mean_mcc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)
std_mcc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)

mean_acc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)
std_acc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)

# %% [markdown]
# Train the pairwise models and store the results

# %%
overall_res = {}

for comp in comparisons:
    
    X_c, y_c = get_pairwise_data(comp[0], comp[1], X_all, y_all)
    results_dict = repeated_training(X_c, y_c, n_repeats, n_folds, rfc_parameters, rfc_bal, mcc_scorer, verbose=1)
    
    rkeys = [x for x in results_dict.keys()][:-1]
    acc = []
    for key in rkeys:
        acc.append(results_dict[key].acc_test)
    mean_acc_df.loc[comp[0], comp[1]] = np.mean(acc)
    std_acc_df.loc[comp[0], comp[1]] = np.std(acc)

    mcc = []
    for key in rkeys:
        mcc.append(results_dict[key].mcc_test)
    mean_mcc_df.loc[comp[0], comp[1]] = np.mean(mcc)
    std_mcc_df.loc[comp[0], comp[1]] = np.std(mcc)
    
    overall_res[comp] = results_dict
# Out:
# Fitting 10 folds for each of 25 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   37.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  4.0min finished
# Run 0 completed
# Fitting 10 folds for each of 25 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   41.5s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.8min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  3.7min finished
# Run 1 completed
# Fitting 10 folds for each of 25 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   33.0s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  2.6min
# ...

# %% [markdown]
# Save the dataframes as CSVs

# %%
mean_mcc_df.to_csv(results_path+subfolder+'mean_mcc_pairwise.csv')
std_mcc_df.to_csv(results_path+subfolder+'std_mcc_pairwise.csv')
mean_acc_df.to_csv(results_path+subfolder+'mean_acc_pairwise.csv')
std_mcc_df.to_csv(results_path+subfolder+'std_acc_pairwise.csv')

# %%
pickle_dump(overall_res, results_path+subfolder+f"overall_res_{nbname}.p")
# Out:
# writing total_bytes=5117176009...
# writing bytes [0, 1073741824)... done.
# writing bytes [1073741824, 2147483648)... done.
# writing bytes [2147483648, 3221225472)... done.
# writing bytes [3221225472, 4294967296)... done.
# writing bytes [4294967296, 5117176009)... done.

# %% [markdown]
# Print the results

# %%
mean_mcc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.692885  0.763794  0.790452  0.610306  0.756966  0.701669
# Down         0.0  0.000000  0.773423  0.775328  0.696027  0.243239  0.425234
# FXS-F        0.0  0.000000  0.000000  0.572694  0.360243  0.793270  0.782474
# FXS-M        0.0  0.000000  0.000000  0.000000  0.407420  0.829034  0.895148
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.830825  0.771259
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.096515
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.930675  0.595055  0.543382
# Down     0.676684  0.477549  0.762408
# ...

# %%
std_mcc_df
# Out:
#          22q11DS     Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.11951  0.099255  0.069152  0.156798  0.134143  0.144797
# Down         0.0  0.00000  0.135591  0.112438  0.105270  0.160915  0.164911
# FXS-F        0.0  0.00000  0.000000  0.127970  0.195228  0.100469  0.112880
# FXS-M        0.0  0.00000  0.000000  0.000000  0.171424  0.143972  0.075325
# NF1          0.0  0.00000  0.000000  0.000000  0.000000  0.129564  0.128939
# PW-UPD       0.0  0.00000  0.000000  0.000000  0.000000  0.000000  0.250466
# PW-del       0.0  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.00000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.077412  0.136795  0.194077
# Down     0.111888  0.111442  0.112045
# ...

# %%
mean_acc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.866667  0.877778  0.891429  0.821429  0.881481  0.860714
# Down         0.0  0.000000  0.873333  0.904545  0.826667  0.600000  0.700000
# FXS-F        0.0  0.000000  0.000000  0.803846  0.678947  0.888889  0.884211
# FXS-M        0.0  0.000000  0.000000  0.000000  0.700000  0.919231  0.946154
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.910526  0.875000
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.547368
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.972000  0.793333  0.792857
# Down     0.830769  0.742424  0.875000
# ...

# %%
std_acc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.055277  0.055060  0.035686  0.071429  0.065838  0.066720
# Down         0.0  0.000000  0.075719  0.047456  0.067987  0.084327  0.078062
# FXS-F        0.0  0.000000  0.000000  0.052876  0.092518  0.055556  0.061378
# FXS-M        0.0  0.000000  0.000000  0.000000  0.083913  0.065385  0.039223
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.066782  0.068007
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.122757
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.031241  0.064444  0.084213
# Down     0.057564  0.068098  0.062500
# ...

# %% [markdown]
# ## Model 7: Weighted Random Forest

# %% [markdown]
# Define a subfolder to store the results

# %%
subfolder = 'WRF/'

# %% [markdown]
# Define the model

# %%
rfc_weighted = RandomForestClassifier(class_weight = 'balanced_subsample')

# %% [markdown]
# Define the parameters for the grid search

# %%
n_features = X_all.shape[1]
default_mtry = np.sqrt(n_features)
rfc_parameters = {'max_features': [int(0.5*default_mtry), int(default_mtry), int(1.5*default_mtry), int(2*default_mtry), int(3*default_mtry)],
             'n_estimators': [2000], 'min_samples_leaf': [1,2, 3, 4, 5]}

# %% [markdown]
# Create dataframes to store the results

# %%
mean_mcc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)
std_mcc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)

mean_acc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)
std_acc_df = pd.DataFrame(np.zeros(((len(labels)),(len(labels)))), index=labels, columns=labels)

# %% [markdown]
# Train the pairwise models and store the results

# %%
overall_res = {}

for comp in comparisons:
    
    X_c, y_c = get_pairwise_data(comp[0], comp[1], X_all, y_all)
    results_dict = repeated_training(X_c, y_c, n_repeats, n_folds, rfc_parameters, rfc_weighted, mcc_scorer, verbose=1)
    
    rkeys = [x for x in results_dict.keys()][:-1]
    acc = []
    for key in rkeys:
        acc.append(results_dict[key].acc_test)
    mean_acc_df.loc[comp[0], comp[1]] = np.mean(acc)
    std_acc_df.loc[comp[0], comp[1]] = np.std(acc)

    mcc = []
    for key in rkeys:
        mcc.append(results_dict[key].mcc_test)
    mean_mcc_df.loc[comp[0], comp[1]] = np.mean(mcc)
    std_mcc_df.loc[comp[0], comp[1]] = np.std(mcc)
    
    overall_res[comp] = results_dict
# Out:
# Fitting 10 folds for each of 25 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   20.3s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  2.0min finished
# Run 0 completed
# Fitting 10 folds for each of 25 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   20.6s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 250 out of 250 | elapsed:  2.1min finished
# Run 1 completed
# Fitting 10 folds for each of 25 candidates, totalling 250 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  34 tasks      | elapsed:   18.7s
# [Parallel(n_jobs=-1)]: Done 184 tasks      | elapsed:  1.5min
# ...

# %% [markdown]
# Save the dataframes as CSVs

# %%
mean_mcc_df.to_csv(results_path+subfolder+'mean_mcc_pairwise.csv')
std_mcc_df.to_csv(results_path+subfolder+'std_mcc_pairwise.csv')
mean_acc_df.to_csv(results_path+subfolder+'mean_acc_pairwise.csv')
std_mcc_df.to_csv(results_path+subfolder+'std_acc_pairwise.csv')

# %%
pickle_dump(overall_res, results_path+subfolder+f"overall_res_{nbname}.p")
# Out:
# writing total_bytes=2019155171...
# writing bytes [0, 1073741824)... done.
# writing bytes [1073741824, 2019155171)... done.

# %% [markdown]
# Print the results

# %%
mean_mcc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.683801  0.656946  0.813999  0.607162  0.681757  0.701738
# Down         0.0  0.000000  0.799149  0.836088  0.687691  0.180609  0.216998
# FXS-F        0.0  0.000000  0.000000  0.517947  0.393889  0.872953  0.828971
# FXS-M        0.0  0.000000  0.000000  0.000000  0.490357  0.909274  0.782655
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.743805  0.783502
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000 -0.011252
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.901521  0.629182  0.595577
# Down     0.710817  0.542458  0.580258
# ...

# %%
std_mcc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.140017  0.089134  0.079970  0.150967  0.148206  0.115750
# Down         0.0  0.000000  0.107209  0.094599  0.182873  0.163958  0.155888
# FXS-F        0.0  0.000000  0.000000  0.084669  0.264693  0.081170  0.110580
# FXS-M        0.0  0.000000  0.000000  0.000000  0.137884  0.068246  0.122829
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.117791  0.096326
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.208288
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.089313  0.086095  0.164104
# Down     0.177439  0.154279  0.132647
# ...

# %%
mean_acc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.870833  0.844444  0.905714  0.817857  0.859259  0.857143
# Down         0.0  0.000000  0.893333  0.936364  0.846667  0.606667  0.631250
# FXS-F        0.0  0.000000  0.000000  0.780769  0.684211  0.933333  0.910526
# FXS-M        0.0  0.000000  0.000000  0.000000  0.761538  0.957692  0.892308
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.863158  0.885000
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.500000
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.960000  0.817778  0.817857
# Down     0.853846  0.851515  0.781250
# ...

# %%
std_acc_df
# Out:
#          22q11DS      Down     FXS-F     FXS-M       NF1    PW-UPD    PW-del  \
# 22q11DS      0.0  0.060237  0.043192  0.040507  0.066720  0.063721  0.059761
# Down         0.0  0.000000  0.061101  0.036364  0.089691  0.075719  0.081250
# FXS-F        0.0  0.000000  0.000000  0.030039  0.126754  0.041574  0.057895
# FXS-M        0.0  0.000000  0.000000  0.000000  0.059086  0.031949  0.059086
# NF1          0.0  0.000000  0.000000  0.000000  0.000000  0.058608  0.050249
# PW-UPD       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.094883
# PW-del       0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# SMC15        0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# TSC          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
# XXY          0.0  0.000000  0.000000  0.000000  0.000000  0.000000  0.000000
#
#             SMC15       TSC       XXY
# 22q11DS  0.035777  0.044222  0.066720
# Down     0.087368  0.045857  0.080283
# ...
